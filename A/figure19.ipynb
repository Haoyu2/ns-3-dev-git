# %%
from utils import *
draw_figure19(2)

# %%
draw_figure19(10)

# %%
draw_figure19(40)

# %%
    draw_fair_throughput(MYQ, SLOWLY)
# Out:
# ['0.2s', '0.4s', '0.6s', '0.8s', '1.0s', '1.2s', '1.4s', '1.6s', '1.8s', '2.0s', '2.2s', '2.4s', '2.6s', '2.8s', '3.0s']

# %%
    draw_fair_throughput(MYQ, ABRUPT)
# Out:
# ['0.2s', '0.4s', '0.6s', '0.8s', '1.0s', '1.2s', '1.4s', '1.6s', '1.8s', '2.0s', '2.2s', '2.4s', '2.6s', '2.8s', '3.0s', '3.2s', '3.4s', '3.6s']

# %%
    draw_fair_throughput(REM, ABRUPT)
# Out:
# ['0.2s', '0.4s', '0.6s', '0.8s', '1.0s', '1.2s', '1.4s', '1.6s', '1.8s', '2.0s', '2.2s', '2.4s', '2.6s', '2.8s', '3.0s', '3.2s', '3.4s', '3.6s']

# %%
    draw_fair_throughput(REM, SLOWLY)
# Out:
# ['0.2s', '0.4s', '0.6s', '0.8s', '1.0s', '1.2s', '1.4s', '1.6s', '1.8s', '2.0s', '2.2s', '2.4s', '2.6s', '2.8s', '3.0s']
